# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import joblib

# %%
df_cleaned = pd.read_csv('cleaned_employee_data.csv')
df_cleaned.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   37          1      Travel_Rarely       1141  Research & Development
# 1   51          1      Travel_Rarely       1323  Research & Development
# 2   42          0  Travel_Frequently        555                   Sales
# 3   40          0      Travel_Rarely       1124                   Sales
# 4   55          1      Travel_Rarely        725  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                11          2        Medical                        1
# 1                 4          4  Life Sciences                        1
# 2                26          3      Marketing                        3
# 3                 1          2        Medical                        2
# 4                 2          3        Medical                        4
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0  Female  ...                  3                         1                 0
# 1    Male  ...                  3                         3                 3
# 2  Female  ...                  3                         4                 1
# 3    Male  ...                  4                         3                 3
# 4    Male  ...                  3                         4                 1
#
#   TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                15                      2               1               1
# 1                18                      2               4              10
# 2                23                      2               4              20
# 3                 6                      2               2               4
# 4                24                      2               3               5
#
#    YearsInCurrentRole  YearsSinceLastPromotion YearsWithCurrManager
# 0                   0                        0                    0
# 1                   0                        2                    7
# 2                   4                        4                    8
# 3                   3                        0                    2
# 4                   2                        1                    4
#
# [5 rows x 31 columns]

# %%
scaler = joblib.load("scaler.pkl")
model = joblib.load("svm_model.pkl")
X_columns = joblib.load("x_columns.pkl")

# %%
# Filter data karyawan yang masih aktif
current_employees = df_cleaned[df_cleaned['Attrition'] == 0].copy()
current_employees.reset_index(drop=True, inplace=True)

# Buat dataframe baru tanpa kolom target
X = current_employees.drop(columns=['Attrition'])

# Identifikasi kolom kategori
categorical_cols = X.select_dtypes(include=['object']).columns

# One-hot encoding
X_encoded = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

# Tambahkan kolom yang hilang agar sesuai dengan data training
missing_cols = set(X_columns) - set(X_encoded.columns)
for col in missing_cols:
    X_encoded[col] = 0

# Pastikan urutan kolom sama seperti saat training
X_encoded = X_encoded[X_columns]

# Normalisasi (scaling)
X_scaled = scaler.transform(X_encoded)

# %%
current_employees.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   42          0  Travel_Frequently        555                   Sales
# 1   40          0      Travel_Rarely       1124                   Sales
# 2   36          0  Travel_Frequently        635  Research & Development
# 3   32          0      Travel_Rarely       1018  Research & Development
# 4   25          0      Travel_Rarely        583                   Sales
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                26          3      Marketing                        3
# 1                 1          2        Medical                        2
# 2                18          1        Medical                        2
# 3                 3          2  Life Sciences                        3
# 4                 4          1      Marketing                        3
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0  Female  ...                  3                         4                 1
# 1    Male  ...                  4                         3                 3
# 2  Female  ...                  3                         1                 0
# 3  Female  ...                  3                         4                 0
# 4    Male  ...                  3                         1                 0
#
#   TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                23                      2               4              20
# 1                 6                      2               2               4
# 2                 8                      2               3               8
# 3                10                      6               3               7
# 4                 5                      1               4               5
#
#    YearsInCurrentRole  YearsSinceLastPromotion YearsWithCurrManager
# 0                   4                        4                    8
# 1                   3                        0                    2
# 2                   1                        1                    7
# 3                   7                        7                    7
# 4                   2                        0                    3
#
# [5 rows x 31 columns]

# %% [markdown]
# Prediksi 10 karyawan dengan probabilitas tertinggi untuk meninggalkan perusahaan

# %%
predicted_attrition_risk = model.predict(X_scaled)
current_employees['PredictedAttrition'] = predicted_attrition_risk
current_employees.sort_values(by='PredictedAttrition', ascending=False).head(10)
# Out:
#      Age  Attrition     BusinessTravel  DailyRate              Department  \
# 471   29          0      Travel_Rarely        144                   Sales
# 575   28          0      Travel_Rarely        640  Research & Development
# 418   22          0      Travel_Rarely        217  Research & Development
# 630   41          0      Travel_Rarely        167  Research & Development
# 208   26          0      Travel_Rarely       1443                   Sales
# 475   30          0  Travel_Frequently       1012  Research & Development
# 206   26          0  Travel_Frequently        496  Research & Development
# 148   25          0      Travel_Rarely        180  Research & Development
# 534   28          0  Travel_Frequently        193  Research & Development
# 94    18          0      Travel_Rarely        812                   Sales
#
#      DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 471                10          1         Marketing                        4
# 575                 1          3  Technical Degree                        4
# 418                 8          1     Life Sciences                        2
# 630                12          4     Life Sciences                        2
# 208                23          3         Marketing                        3
# 475                 5          4     Life Sciences                        2
# 206                11          2           Medical                        1
# 148                 2          1           Medical                        1
# 534                 2          3     Life Sciences                        4
# 94                 10          3           Medical                        4
#
#      Gender  ...  RelationshipSatisfaction  StockOptionLevel  \
# 471  Female  ...                         1                 2
# 575    Male  ...                         2                 0
# 418    Male  ...                         1                 1
# 630    Male  ...                         1                 1
# 208  Female  ...                         3                 1
# 475    Male  ...                         2                 1
# 206    Male  ...                         3                 1
# 148    Male  ...                         3                 0
# 534    Male  ...                         2                 1
# 94   Female  ...                         1                 0
#
#      TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# 471                  7                     2                3              7
# 575                  5                     2                2              3
# 418                  4                     3                2              4
# 630                  6                     4                3              1
# 208                  5                     2                2              2
# 475                 10                     3                2              5
# 206                  5                     3                3              5
# 148                  6                     3                2              4
# 534                  2                     2                3              2
# 94                   0                     2                3              0
#
#      YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 471                   7                        1                     7
# 575                   2                        1                     2
# 418                   3                        1                     1
# 630                   0                        0                     0
# 208                   2                        0                     0
# 475                   4                        0                     3
# 206                   3                        3                     3
# 148                   3                        0                     1
# 534                   2                        2                     2
# 94                    0                        0                     0
#
#     PredictedAttrition
# 471                  1
# 575                  1
# 418                  1
# 630                  1
# 208                  1
# 475                  1
# 206                  1
# 148                  1
# 534                  1
# 94                   1
#
# [10 rows x 32 columns]
